# %%
# !git clone https://github.com/0alfajar/arabic-whisper-finetune.git
# Out:
# Cloning into 'arabic-whisper-finetune'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 58 (delta 26), reused 26 (delta 25), pack-reused 22 (from 1)
# Receiving objects: 100% (58/58), 22.01 KiB | 3.14 MiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %%
# 1. Pastikan posisi foldernya benar
# %cd /kaggle/working/arabic-whisper-finetune/

# 2. Patching / Ganti kode yang error secara otomatis di dalam file
# !sed -i 's/model.config.max_length/model.config.max_target_positions/g' train/fine-tune_on_hf_dataset.py

# 3. Gas training lagi!
# !/usr/bin/python3 -m torch.distributed.run --nproc_per_node=2 train/fine-tune_on_hf_dataset.py \
  --model_name "openai/whisper-tiny" \
  --language "Arabic" \
  --sampling_rate 16000 \
  --num_proc 2 \
  --train_strategy "steps" \
  --learning_rate 3.75e-5 \
  --warmup 500 \
  --train_batchsize 8 \
  --eval_batchsize 8 \
  --num_steps 4000 \
  --output_dir "/kaggle/working/whisper-everyayah-model" \
  --train_datasets "tarteel-ai/everyayah" \
  --train_dataset_configs "default" \
  --train_dataset_splits "train" \
  --train_dataset_text_columns "text" \
  --eval_datasets "tarteel-ai/everyayah" \
  --eval_dataset_configs "default" \
  --eval_dataset_splits "validation" \
  --eval_dataset_text_columns "text"
# Out:
# /kaggle/working/arabic-whisper-finetune
#
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# Traceback (most recent call last):
#   File "/kaggle/working/arabic-whisper-finetune/train/fine-tune_on_hf_dataset.py", line 3, in <module>
#     import evaluate
# ModuleNotFoundError: No module named 'evaluate'
# Traceback (most recent call last):
#   File "/kaggle/working/arabic-whisper-finetune/train/fine-tune_on_hf_dataset.py", line 3, in <module>
#     import evaluate
# ModuleNotFoundError: No module named 'evaluate'
# E0405 08:45:51.336000 56 torch/distributed/elastic/multiprocessing/api.py:984] failed (exitcode: 1) local_rank: 0 (pid: 62) of binary: /usr/bin/python3
# Traceback (most recent call last):
# ...
